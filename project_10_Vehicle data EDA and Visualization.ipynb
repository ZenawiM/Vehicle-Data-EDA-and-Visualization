# %% [markdown]
# <a id="1"></a>
# # <p style="background-color:#0388fc;font-family:newtimeroman;color:#FFF9ED;font-size:150%;text-align:center;border-radius:10px 10px;">Importing Libraries</p>

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

import os
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %% [markdown]
# <a id="2"></a>
# # <p style="background-color:#0388fc;font-family:newtimeroman;color:#FFF9ED;font-size:150%;text-align:center;border-radius:10px 10px;"> Reading Data</p>

# %%
vehicle_data = pd.read_csv('vehicle_data.csv')
# Out:
# /home/shahrayar/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# <a id="3"></a>
# # <p style="background-color:#0388fc;font-family:newtimeroman;color:#FFF9ED;font-size:150%;text-align:center;border-radius:10px 10px;">Displaying top 5 records</p>

# %%
vehicle_data.head()
# Out:
#                                       Title  \
# 0         Honda Vezel Limited 2017 for sale
# 1      Jaguar XF Fully Loaded 2013 for sale
# 2  Toyota CHR GT New Face 2wd 2020 for sale
# 3           Toyota CHR Toyato 2017 for sale
# 4   Toyota Land Cruiser Prado 2015 for sale
#
#                                            Sub_title          Price   Brand  \
# 0  Posted on 01 Sep 2:45 pm, Kurunegala City, Kur...  Rs 12,900,000   Honda
# 1  Posted on 28 Sep 10:23 am, Kurunegala City, Ku...  Rs 16,250,000  Jaguar
# 2       Posted on 16 Sep 1:16 pm, Colombo 7, Colombo  Rs 17,000,000  Toyota
# 3      Posted on 30 Sep 10:12 am, Colombo 7, Colombo  Rs 13,000,000  Toyota
# 4        Posted on 30 Sep 9:50 pm, Kelaniya, Gampaha  Rs 33,500,000  Toyota
#
#                 Model          Edition  Year Condition Transmission  \
# 0               Vezel          Limited  2017      Used    Automatic
# 1                  XF     Fully Loaded  2013      Used    Automatic
# ...

# %% [markdown]
# <a id="4"></a>
# # <p style="background-color:#0388fc;font-family:newtimeroman;color:#FFF9ED;font-size:150%;text-align:center;border-radius:10px 10px;">📝 Meta information about dataframe</p>

# %% [markdown]
# <a id="4.1"></a>
# <p style="background-color:#5cb3ff;font-family:newtimeroman;color:#FFF9ED;font-size:120%;text-align:center;border-radius:20px 80px;">Shape of dataframe</p>

# %%
vehicle_data.shape
# Out:
# (23303, 19)

# %% [markdown]
# <a id="4.2"></a>
# <p style="background-color:#5cb3ff;font-family:newtimeroman;color:#FFF9ED;font-size:120%;text-align:center;border-radius:20px 80px;">Datatype of Each Column</p>

# %%
vehicle_data.dtypes
# Out:
# Title             object
# Sub_title         object
# Price             object
# Brand             object
# Model             object
# Edition           object
# Year               int64
# Condition         object
# Transmission      object
# Body              object
# Fuel              object
# Capacity          object
# Mileage           object
# Location          object
# Description       object
# Post_URL          object
# Seller_name       object
# Seller_type       object
# published_date    object
# dtype: object

# %% [markdown]
# <a id="5"></a>
# # <p style="background-color:#0388fc;font-family:newtimeroman;color:#FFF9ED;font-size:150%;text-align:center;border-radius:10px 10px;">🧹 Data Cleaning</p>

# %% [markdown]
# <a id="5.1"></a>
# <p style="background-color:#5cb3ff;font-family:newtimeroman;color:#FFF9ED;font-size:120%;text-align:center;border-radius:20px 80px;">Finding NaN values</p>

# %%
plt.figure(figsize = (10,6))
plt.title("Missing values in Each Column\n", size = 15)
sns.heatmap(vehicle_data.isnull(), yticklabels=False, cbar=False);

# %% [markdown]
# ## **Edition** and **Body** has missing values

# %%
for col in ['Edition', 'Body']:
    missing_percent = np.round((vehicle_data[col].isnull().sum() * 100) / vehicle_data.shape[0], 3)
    print(f'{missing_percent} % data is miss in `{col}` column')
# Out:
# 25.473 % data is miss in `Edition` column
# 9.454 % data is miss in `Body` column

# %% [markdown]
# <a id="5.2"></a>
# <p style="background-color:#5cb3ff;font-family:newtimeroman;color:#FFF9ED;font-size:120%;text-align:center;border-radius:20px 80px;">Imputing missing values</p>

# %%
vehicle_data['Edition'].fillna(vehicle_data['Edition'].mode()[0], inplace = True)
vehicle_data['Body'].fillna(vehicle_data['Body'].mode()[0], inplace = True)

# %%
vehicle_data.isnull().sum()
# Out:
# Title             0
# Sub_title         0
# Price             0
# Brand             0
# Model             0
# Edition           0
# Year              0
# Condition         0
# Transmission      0
# Body              0
# Fuel              0
# Capacity          0
# Mileage           0
# Location          0
# Description       0
# Post_URL          0
# Seller_name       0
# Seller_type       0
# published_date    0
# dtype: int64

# %% [markdown]
# #### **All missing values are now fixed**

# %% [markdown]
# <a id="5.3"></a>
# <p style="background-color:#5cb3ff;font-family:newtimeroman;color:#FFF9ED;font-size:120%;text-align:center;border-radius:20px 80px;">Convert dtype of Price feature</p>

# %%
vehicle_data.rename({"Price":"Price (Rs)"}, axis = 1, inplace = True)

# %%
vehicle_data['Price (Rs)'] = vehicle_data['Price (Rs)'].str.replace('Rs', '').str.replace(',', '').astype(float)

# %% [markdown]
# <a id="5.4"></a>
# <p style="background-color:#5cb3ff;font-family:newtimeroman;color:#FFF9ED;font-size:120%;text-align:center;border-radius:20px 80px;">Convert dtype of Capacity</p>

# %%
vehicle_data.rename({"Capacity" : "Capacity(cc)"}, axis = 1, inplace = True)

# %%
vehicle_data['Capacity(cc)'] = vehicle_data['Capacity(cc)'].str.replace('cc', '').str.replace(',', '').astype('int64')

# %% [markdown]
# <a id="5.5"></a>
# <p style="background-color:#5cb3ff;font-family:newtimeroman;color:#FFF9ED;font-size:120%;text-align:center;border-radius:20px 80px;">Convert dtype of Milage</p>

# %%
vehicle_data.rename({"Mileage" : "Mileage(km)"}, axis = 1, inplace = True)

# %%
vehicle_data['Mileage(km)'] = vehicle_data['Mileage(km)'].str.replace('km', '').str.replace(',', '').astype('int64')

# %%
vehicle_data.head()
# Out:
#                                           Title  \
# 0                Micro Panda Auto 2019 for sale
# 1  Toyota GT86 Company Maintained 2013 for sale
# 2           Toyota IST FL , GRADE 2003 for sale
# 3               Toyota Allion 240 2002 for sale
# 4              Micro Panda LC 1.0 2015 for sale
#
#                                        Sub_title  Price (Rs)   Brand   Model  \
# 0     Posted on 02 Jul 6:27 am, Kesbewa, Colombo   2795000.0   Micro   Panda
# 1  Posted on 15 Jun 7:38 pm, Rajagiriya, Colombo  11500000.0  Toyota    GT86
# 2   Posted on 05 Jul 1:36 pm, Marawila, Puttalam   3300000.0  Toyota     IST
# 3    Posted on 05 Jul 1:33 pm, Peradeniya, Kandy   4450000.0  Toyota  Allion
# 4   Posted on 05 Jul 1:30 pm, Veyangoda, Gampaha   2173000.0   Micro   Panda
#
#               Edition  Year Condition Transmission           Body    Fuel  \
# 0                Auto  2019      Used    Automatic      Hatchback  Petrol
# ...

# %% [markdown]
# <a id="5.6"></a>
# <p style="background-color:#5cb3ff;font-family:newtimeroman;color:#FFF9ED;font-size:120%;text-align:center;border-radius:20px 80px;">Shorten Title</p>

# %%
vehicle_data['Title'] = vehicle_data['Brand'] + " "+ vehicle_data['Model']

# %% [markdown]
# <a id="5.7"></a>
# <p style="background-color:#5cb3ff;font-family:newtimeroman;color:#FFF9ED;font-size:120%;text-align:center;border-radius:20px 80px;">Converting type of published_date feature to datetime</p>

# %%
vehicle_data['published_date'] = pd.to_datetime(vehicle_data['published_date'])

# %% [markdown]
# <a id="5.8"></a>
# <p style="background-color:#5cb3ff;font-family:newtimeroman;color:#FFF9ED;font-size:120%;text-align:center;border-radius:20px 80px;">Seperate year, month, day from published_date</p>

# %%
# for year
vehicle_data['published_year'] = pd.DatetimeIndex(vehicle_data['published_date']).year

# for month
vehicle_data['published_month'] = pd.DatetimeIndex(vehicle_data['published_date']).month

# for day
vehicle_data['published_day'] = pd.DatetimeIndex(vehicle_data['published_date']).day

# %%
vehicle_data.columns
# Out:
# Index(['Title', 'Sub_title', 'Price (Rs)', 'Brand', 'Model', 'Edition', 'Year',
#        'Condition', 'Transmission', 'Body', 'Fuel', 'Capacity(cc)',
#        'Mileage(km)', 'Location', 'Description', 'Post_URL', 'Seller_name',
#        'Seller_type', 'published_date', 'published_year', 'published_month',
#        'published_day'],
#       dtype='object')

# %% [markdown]
# <a id="5.9"></a>
# <p style="background-color:#5cb3ff;font-family:newtimeroman;color:#FFF9ED;font-size:120%;text-align:center;border-radius:20px 80px;">Dropping unnecessary features</p>

# %%
vehicle_data.drop(["Sub_title",'Description', 'published_date'], axis = 1, inplace = True)

# %% [markdown]
# <a id="6"></a>
# # <p style="background-color:#0388fc;font-family:newtimeroman;color:#FFF9ED;font-size:150%;text-align:center;border-radius:10px 10px;">📈 Checking statistical description of data</p>

# %%
vehicle_data.describe().T.style.bar(subset=['mean'], color='#205ff2')\
                            .background_gradient(subset=['std'], cmap='Reds')\
                            .background_gradient(subset=['50%'], cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_855dd_row0_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 100.0%, transparent 100.0%);
#         }#T_855dd_row0_col2{
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }#T_855dd_row0_col5{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_855dd_row1_col1,#T_855dd_row2_col1,#T_855dd_row4_col1,#T_855dd_row6_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 0.0%, transparent 0.0%);
#         }#T_855dd_row1_col2,#T_855dd_row2_col2,#T_855dd_row4_col2,#T_855dd_row5_col2,#T_855dd_row6_col2{
#             background-color:  #fff5f0;
#             color:  #000000;
#         }#T_855dd_row1_col5,#T_855dd_row2_col5,#T_855dd_row4_col5,#T_855dd_row5_col5,#T_855dd_row6_col5{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
# ...

# %% [markdown]
# **Price(Rs) has highest standard deviation among other features**

# %%
vehicle_data.head()
# Out:
#            Title  Price (Rs)   Brand   Model             Edition  Year  \
# 0    Micro Panda   2795000.0   Micro   Panda                Auto  2019
# 1    Toyota GT86  11500000.0  Toyota    GT86  Company Maintained  2013
# 2     Toyota IST   3300000.0  Toyota     IST          FL , GRADE  2003
# 3  Toyota Allion   4450000.0  Toyota  Allion                 240  2002
# 4    Micro Panda   2173000.0   Micro   Panda              LC 1.0  2015
#
#   Condition Transmission           Body    Fuel  Capacity(cc)  Mileage(km)  \
# 0      Used    Automatic      Hatchback  Petrol          1000        14000
# 1      Used    Automatic  CoupÃ©/Sports  Petrol          2000        27000
# 2      Used    Automatic      Hatchback  Petrol          1300       150000
# 3      Used    Automatic         Saloon  Petrol          1500       124000
# 4      Used       Manual      Hatchback  Petrol          1000        15800
#
#                 Location                                           Post_URL  \
# ...

# %% [markdown]
# <a id="7"></a>
# # <p style="background-color:#0388fc;font-family:newtimeroman;color:#FFF9ED;font-size:150%;text-align:center;border-radius:10px 10px;">Declaring a function that convert links to clickable</p>

# %%
def clickable(path):        
    final_url = os.path.basename(path)
      
    # convert the url into link
    return f'<a href="{path}">{final_url}</a>'

# %% [markdown]
# <a id="8"></a>
# # <p style="background-color:#0388fc;font-family:newtimeroman;color:#FFF9ED;font-size:150%;text-align:center;border-radius:10px 10px;"> Visualization</p>

# %% [markdown]
# <a id="8.1"></a>
# <p style="background-color:#5cb3ff;font-family:newtimeroman;color:#FFF9ED;font-size:120%;text-align:center;border-radius:20px 80px;">Analyze top 20 vehicle with highest Price</p>

# %%
top_highest_price = vehicle_data.sort_values("Price (Rs)", ascending = False).reset_index().head(20)

# %%
px.scatter(top_highest_price, x = "Title", y = "Price (Rs)",
           size = "Price (Rs)",
           hover_data=['Condition', 'Transmission', 'Fuel','Price (Rs)'],
           color = "Transmission")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %% [markdown]
# **`Mitsubishi Montero` is more expensive then other vehicle (I consider it as outlier). Also from top 20 expensive vehicles most of them are `Land Rover Range Rover`**

# %%
top_highest_price[['Title', 'Price (Rs)','Capacity(cc)', 'Post_URL']].style.format({'Post_URL' : clickable})
# Out:
# <style  type="text/css" >
# </style><table id="T_a2bc4_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Title</th>        <th class="col_heading level0 col1" >Price (Rs)</th>        <th class="col_heading level0 col2" >Capacity(cc)</th>        <th class="col_heading level0 col3" >Post_URL</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a2bc4_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_a2bc4_row0_col0" class="data row0 col0" >Mitsubishi Montero</td>
#                         <td id="T_a2bc4_row0_col1" class="data row0 col1" >210000000.000000</td>
#                         <td id="T_a2bc4_row0_col2" class="data row0 col2" >3200</td>
#                         <td id="T_a2bc4_row0_col3" class="data row0 col3" ><a href="https://ikman.lk/en/ad/mitsubishi-montero-gls-2015-for-sale-gampaha-40">mitsubishi-montero-gls-2015-for-sale-gampaha-40</a></td>
# ...

# %% [markdown]
# ### **Click on the link to go to original post**

# %% [markdown]
# <a id="8.2"></a>
# <p style="background-color:#5cb3ff;font-family:newtimeroman;color:#FFF9ED;font-size:120%;text-align:center;border-radius:20px 80px;">Analyze top 20 vehicle with lowest Price</p>

# %%
lowest_price_vehicle = vehicle_data.sort_values("Price (Rs)", ascending = True).reset_index().head(20)

# %%
px.scatter(lowest_price_vehicle, x = "Title", y = "Price (Rs)",
           size = "Price (Rs)",
           hover_data=['Condition', 'Transmission', 'Fuel','Price (Rs)'],
           color = "Transmission")
# Out:
# <div>                            <div id="d2bf3e26-f04b-45b1-9956-f64ede1a1623" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d2bf3e26-f04b-45b1-9956-f64ede1a1623")) {                    Plotly.newPlot(                        "d2bf3e26-f04b-45b1-9956-f64ede1a1623",                        [{"customdata":[["Used","Automatic","Petrol"],["Used","Automatic","Petrol"],["Used","Automatic","Petrol"]],"hovertemplate":"Transmission=%{customdata[1]}<br>Title=%{x}<br>Price (Rs)=%{marker.size}<br>Condition=%{customdata[0]}<br>Fuel=%{customdata[2]}<extra></extra>","legendgroup":"Automatic","marker":{"color":"#636efa","size":[990.0,2100.0,85000.0],"sizemode":"area","sizeref":562.5,"symbol":"circle"},"mode":"markers","name":"Automatic","orientation":"v","showlege
# ...

# %%
lowest_price_vehicle[['Title', 'Price (Rs)','Capacity(cc)', 'Post_URL']].style.format({'Post_URL' : clickable})
# Out:
# <style  type="text/css" >
# </style><table id="T_9f9de_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Title</th>        <th class="col_heading level0 col1" >Price (Rs)</th>        <th class="col_heading level0 col2" >Capacity(cc)</th>        <th class="col_heading level0 col3" >Post_URL</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9f9de_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_9f9de_row0_col0" class="data row0 col0" >Toyota Vitz</td>
#                         <td id="T_9f9de_row0_col1" class="data row0 col1" >990.000000</td>
#                         <td id="T_9f9de_row0_col2" class="data row0 col2" >990</td>
#                         <td id="T_9f9de_row0_col3" class="data row0 col3" ><a href="https://ikman.lk/en/ad/toyota-vitz-2010-for-sale-colombo-914">toyota-vitz-2010-for-sale-colombo-914</a></td>
#             </tr>
#             <tr>
# ...

# %% [markdown]
# ### **Click on the link to go to original post**

# %% [markdown]
# <a id="8.3"></a>
# <p style="background-color:#5cb3ff;font-family:newtimeroman;color:#FFF9ED;font-size:120%;text-align:center;border-radius:20px 80px;">Analyze vehicle_data, Condition wise</p>

# %%
px.histogram(vehicle_data, x='Condition', barmode='group', color="Transmission",)
# Out:
# <div>                            <div id="b8f11126-1794-4ba4-bd2e-b063421f92c0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b8f11126-1794-4ba4-bd2e-b063421f92c0")) {                    Plotly.newPlot(                        "b8f11126-1794-4ba4-bd2e-b063421f92c0",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Transmission=Automatic<br>Condition=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Automatic","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Automatic","offsetgroup":"Automatic","orientation":"v","showlegend":true,"type":"histogram","x":["Used","Used","Used","Used","Used","Used","Used","Used","New","Used","Used","Used","Used","Used","Used","Used","Used","Used","Used","Used","Used","Used","Us
# ...

# %% [markdown]
# **So most of the vehicles are in Used condition and Transmission type is Automatic**

# %% [markdown]
# <a id="8.4"></a>
# <p style="background-color:#5cb3ff;font-family:newtimeroman;color:#FFF9ED;font-size:120%;text-align:center;border-radius:20px 80px;">Analyze data by Fuel type</p>

# %%
px.histogram(vehicle_data, x='Fuel', barmode='group', color="Transmission",)
# Out:
# <div>                            <div id="4db87c17-0604-4117-a303-ff5d2e8fed7d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4db87c17-0604-4117-a303-ff5d2e8fed7d")) {                    Plotly.newPlot(                        "4db87c17-0604-4117-a303-ff5d2e8fed7d",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Transmission=Automatic<br>Fuel=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Automatic","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Automatic","offsetgroup":"Automatic","orientation":"v","showlegend":true,"type":"histogram","x":["Petrol","Petrol","Petrol","Petrol","Petrol","Petrol","Hybrid","Petrol","Petrol","Petrol","Diesel","Diesel","Petrol","Petrol","Hybrid","Petrol","Hybrid","Petrol"
# ...

# %% [markdown]
# <a id="8.5"></a>
# <p style="background-color:#5cb3ff;font-family:newtimeroman;color:#FFF9ED;font-size:120%;text-align:center;border-radius:20px 80px;">Analyze Year and published_year</p>

# %%
desending_price = vehicle_data.sort_values("Price (Rs)", ascending=False).reset_index().drop('index', axis = 1)

# %%
ascending_price = vehicle_data.sort_values("Price (Rs)", ascending=True).reset_index().drop('index', axis = 1)

# %%
plt.figure(figsize=(20,8))

plt.title("Difference in Manufactured Year & Selling Year of Top 100 Expensive Vehicles\n", size = 22)

plt.plot(desending_price['Year'].head(100), marker = 'o', label = "Manufactured Year", markerfacecolor = 'red')
plt.plot(desending_price['published_year'].head(100), marker = 'o', markersize=4, label = "Selling Year", markerfacecolor = 'red')

plt.ylabel("Year")

plt.grid()
plt.legend(loc = 5);

# %%
plt.figure(figsize=(20,8))

plt.title("Difference in Manufactured Year & Selling Year of Top 100 Inexpensive Vehicles\n", size = 22)

plt.plot(ascending_price['Year'].head(100), marker = 'o', label = "Manufactured Year", markerfacecolor = 'red')
plt.plot(ascending_price['published_year'].head(100), marker = 'o', markersize=4, label = "Selling Year", markerfacecolor = 'red')

plt.ylabel("Year")
plt.grid()
plt.legend(loc = 4);
